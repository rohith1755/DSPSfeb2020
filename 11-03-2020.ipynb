# %% [markdown]
# #YESTERDAYS SOLUTIONS

# %%
#4.
a = [27,25,56,12,19,30]
for i in range(1,len(a),2):
  a[i] = a[i] ** 2
a

# %%
#3. 
out = []
for i in range(0,100,10): #for accessing a list of values from to 100 with step 10.
  out.append(list(range(i,i+10)))  # first get all the elements from 1 to 10 using i+10 and then convert it into list and then append it to the existing empty list.
out[6][5] #getting 7th row 6th element.

# %%
#5. a = [27,24,12,19,30]
# o/p: [27,576, 144, 19 ,900]
a = [27, 24, 12, 19, 30]
i = 1
for i in range(len(a)):
    if (a[i] % 6) ==0: # number must be divisible by 2 and 3
        a[i] = a[i] ** 2
a
# Out:
# [27, 576, 144, 19, 900]

# %%
a = [27, 24, 12, 19, 30]
b = []
for i in range(len(a)):
    if (a[i] % 6) ==0:
        b.append(a[i] ** 2)
    else:
        b.append(a[i])
b
# Out:
# [27, 576, 144, 19, 900]

# %%
a = [27, 24, 12, 19, 30]
b = []
for i in a:
    if i % 6 ==0:
        b. append(i ** 2)
    else:
        b. append(i)
b
# Out:
# [27, 576, 144, 19, 900]

# %%
b = a
print(b)
# Out:
# [27, 24, 12, 19, 30]

# %%
a = [27, 24, 12, 19, 30]
b = a.copy()     # we can also use b = a[:] instead of copy().
for i in range(len(a)):
    if a[i] % 6 ==0:
        b[i] = b[i] **2
b
# Out:
# [27, 576, 144, 19, 900]

# %% [markdown]
# #TUPLES
# - empty tuples
# - tuple with elements
# - immutable
# - operators on two tuples
# - access the elements in a tuple.

# %%
t = ()
dir(t)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
t.count(1)
# Out:
# 0

# %%
'''+ = appends one tuple to another
* = repeats the tuple  you cannot multiply 2 tuples. '''

# %% [markdown]
# #SETS
# - An unordered list which does not allow subscripting(Access elements using indexing).

# %%
s = set() #defines an empty set. 
# to access elements in set convert it into list and then use indexing. 
print(dir(s))
# Out:
# ['__and__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
dir(s)
# Out:
# ['__and__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
s1= { 23,35,67,23,45,4}
s3 = {2,3,4,45,3,4}
s1.difference(s1)
# Out:
# set()

# %%
help(s.difference_update)
# Out:
# Help on built-in function difference_update:
#
# difference_update(...) method of builtins.set instance
#     Remove all elements of another set from this set.

# %%
s1.difference_update(s3)
print(s1)
# Out:
# {67, 35, 23}

# %%
s1.symmetric_difference_update(s3)
print(s1)
help(s.symmetric_difference_update)
# Out:
# {2, 67, 35, 3, 4, 45, 23}
# Help on built-in function symmetric_difference_update:
#
# symmetric_difference_update(...) method of builtins.set instance
#     Update a set with the symmetric difference of itself and another.

# %% [markdown]
# #QUESTIONS
# 1. Read the input from keyboard
#    - i/p  "23 44 67 92 99"
#     - o/p : [3,4,7,2,9]
#     - Try the problem in two ways
#     - to update the same list
#     - to create a new list
# 2. Read the inputs from keyboard
#   -  i/p1: "10 20 30 60 99"
#   -  i/p2: "7 6 9 11 9"
#   -  o/p1: [3,2,3,5,0]
#   -  o/p2 : [1,3,3,5,11]

# %%
#1.
#My code
n = input()
l = n.split()
for i in range(len(l)):
    print(l[i][-1], end=" ") #append it in new list to get output as list.
# Out:
# 23 44 67 92 99
# 3 4 7 2 9

# %%
#method 2: 
s = input()
nums = s.split()
out = []
for i in nums:
    out.append(int(i[-1]))
print(out)
# Out:
# 23 44 67 92 99
# [3, 4, 7, 2, 9]

# %%
#without creating new list and modifying the original list
s = input()
nums = s.split()
for i in range(len(nums)):
    nums[i] = int(nums[i][-1])
nums
# Out:
# 34252 234523 135 3422
# [2, 3, 5, 2]

# %%
#2. 
n = input().split()
n1 = input().split()
l = []
l1 = []
for i in range(len(n)):
    n[i] = int(n[i])
    n1[i] = int(n1[i])
    l.append(n[i] % n1[i])
    l1.append(n[i]/ n1[i])
print(l)
print(l1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# ...

# %%
()
